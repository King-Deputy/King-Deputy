# %%
#Importing Necessary Package
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#Read file from SPSS
df= pd.read_spss('C:/Users/Dell/Desktop/project/DN BATCH 6/Qudus/Qudus Friend 2.sav')

#print the first 10 cases
df.head(10)

#print the last 10 cases
df.tail(10)
# Out:
#            ACM_Type            Edu_Level       hospital    Age    PVC  \
# 590  Sefl_Contained            Secondary  CIVIL SERVICE  21-25  21-30
# 591    Face_to_Face  No Formal Education           UITH    1-5  31-40
# 592    Face_to_Face  No Formal Education           UITH    1-5  31-40
# 593    Face_to_Face  No Formal Education           UITH    1-5  31-40
# 594    Face_to_Face  No Formal Education           UITH   6-10  31-40
# 595  Sefl_Contained            Secondary           SOBI  16-20  31-40
# 596  Sefl_Contained             Tertiary            GHI  36-40    <15
# 597    Face_to_Face              Primary           UITH   6-10  31-40
# 598  Sefl_Contained            Secondary           SOBI  11-15  31-40
# 599    Face_to_Face              Primary           UITH   6-10  15-20
#
#     Blood_Group     Sex Genotype      PD   PD_Group Age_Bracket   Pos_Neg
# 590         AB+    Male       AS     NaN        nil         >15  Negative
# ...

# %%
#Examining the data info
df.info()

#Education Level has 9 missing cases
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ACM_Type     600 non-null    category
#  1   Edu_Level    600 non-null    category
#  2   hospital     600 non-null    category
#  3   Age          600 non-null    category
#  4   PVC          600 non-null    category
#  5   Blood_Group  600 non-null    category
#  6   Sex          600 non-null    category
#  7   Genotype     600 non-null    category
#  8   PD           178 non-null    float64
#  9   PD_Group     600 non-null    category
#  10  Age_Bracket  600 non-null    category
#  11  Pos_Neg      600 non-null    category
# dtypes: category(11), float64(1)
# memory usage: 13.3 KB

# %%
#Running the cross tabulation for the categorical variables against SNP
print("Chi-Square Analysis\n")
col=['ACM_Type','Edu_Level', 'hospital', 'PVC','Blood_Group', 'Sex','Genotype', 'Age_Bracket',]
alpha=0.05
for i in col:
    df_crosstab=pd.crosstab(df[i], df['Pos_Neg'], margins=True)
    print (df_crosstab)
    df_crosstab=df_crosstab.iloc[ :-1 , :-1]
    stat, p, dof, expected=chi2_contingency(df_crosstab)
    print("Chi-square between", i, "and Parasite Density Status")
    print("Chisquare Statz= ", stat)
    print("p-value= ", p)
    print("degree of freedom= ", dof)
    if p<=alpha:
        print("There is significant relationship between", i, "and Parasite Density Status")
        print("The reason is because the associated p-value (",round(p, 4),") is lesser than 0.05")
    else:
        print("There is no significant relationship between", i, "and Parasite Density Status")
        print("The reason is because the associated p-value (",round(p, 7),") is greater than 0.05")
    print("\n")
# Out:
# Chi-Square Analysis
#
# Pos_Neg         Negative  Positive  All
# ACM_Type
# Face_to_Face         103       115  218
# Sefl_Contained       319        63  382
# All                  422       178  600
# Chi-square between ACM_Type and Parasite Density Status
# Chisquare Statz=  85.72847737433885
# p-value=  2.064187365797288e-20
# degree of freedom=  1
# There is significant relationship between ACM_Type and Parasite Density Status
# The reason is because the associated p-value ( 0.0 ) is lesser than 0.05
#
#
# Pos_Neg              Negative  Positive  All
# Edu_Level
# No Formal Education        55        42   97
# Primary                    52        38   90
# Secondary                 146        34  180
# Tertiary                  169        64  233
# All                       422       178  600
# Chi-square between Edu_Level and Parasite Density Status
# Chisquare Statz=  25.999624776325476
# p-value=  9.539132374743257e-06
# degree of freedom=  3
# ...
