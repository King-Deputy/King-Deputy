# %%
import numpy as np
import matplotlib.pyplot as plt
a=np.linspace(-np.pi,np.pi,256,endpoint=True)
C,S=np.cos(a),np.sin(a)
plt.plot(a,C)
plt.plot(a,S)
plt.show()

# %%
from pylab import *
#create a new figure of size 8x6 points, using 80 dots per inch
figure(figsize=(8,6),dpi=80)

#create a new subplot from a grid of 1x1
subplot(1,1,1)
X=np.linspace(-np.pi,np.pi,256,endpoint=True)
C,S=np.cos(X),np.sin(X)

#plot cosine using blue color with a continuous line of width 1 (pixels)
plot(X,C,color="blue",linewidth=1.0,linestyle="-")

#plot cosine using blue color with a continuous line of width 1 (pixels)
plot(X,S,color="green",linewidth=1.0,linestyle="-")

#set x limits
xlim(-4.0,4.0)

#set y limits
ylim(-1.0,1.0)

#set y ticks
yticks(np.linspace(-1,1,5,endpoint=True))

#save figure using 72 dots per inch
savefig("exercise_2.png",dpi=72)

#show result on screen
show()

# %%
from pylab import *
#changing figure of size 10x6 points, using 80 dots per inch
figure(figsize=(10,6),dpi=80)
subplot(2,1,1)

X=np.linspace(-np.pi,np.pi,256,endpoint=True)
C,S=np.cos(X),np.sin(X)

#plot cosine using blue color with a continuous line of width 2.5 (pixels)
plot(X,C,color="blue",linewidth=2.5,linestyle="-")

#plot cosine using red color with a continuous line of width 1 (pixels)
plot(X,S,color="red",linewidth=2.5,linestyle="-")

#to make space in order to clearly see all data point
#changing x limits
xlim(X.min()*1.1,X.max()*1.1)

#changing y limits
ylim(C.min()*1.1,C.max()*1.1)

#changing the ticks so that they show interesting values
#changing x and y ticks
xticks([-np.pi,-np.pi/2,0,np.pi/2,np.pi])
yticks([-1,0,+1])

#setting ticks label
xticks([-np.pi,-np.pi/2,0,np.pi/2,np.pi],[r'$-\pi$',r'$-\pi/2$',r'$0$',r'$+\pi$',r'$+\pi/2$'])
yticks([-1,0,+1],[r'$-1$',r'$0$',r'$+1$'])

#save figure using 72 dots per inch
savefig("exercise_3.png",dpi=72)
show()
#show result on screen


#Moving Spine
#spines are lines connecting the axis tick marks and noting the boundaries of the data axis
#we would wish to have them in the middle
subplot(2,1,2)
ax=gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

#Adding Legend
plot(X,C,color="blue",linewidth=2.5,linestyle="-",label="cosine")
plot(X,S,color="red",linewidth=2.5,linestyle="-",label="sine")
legend(loc='upper left')

#Annotate some points
t=2*np.pi/3
plot([t,t],[0,np.cos(t)],color='blue',linewidth=2.5,linestyle="--")
scatter([t,],[np.cos(t),],50,color='blue')
annotate(r'$\sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
        xy=(t,np.sin(t)),xycoords='data',
        xytext=(+10,+30),textcoords='offset points',fontsize=16,
        arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))
plot([t,t],[0,np.sin(t)],color='red',linewidth=2.5,linestyle="--")
scatter([t,],[np.sin(t),],50,color='red')
annotate(r'$\cos(\frac{2\pi}{3})=-\frac{1}{2}$',
        xy=(t,np.cos(t)),xycoords='data',
        xytext=(-90,-50),textcoords='offset points',fontsize=16,
        arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

#Devil is in the details
#to see both the data and the labels
for label in ax.get_xticklabels()+ax.get_yticklabels():
    label.set_fontsize(16)
    label.set_bbox(dict(facecolor='white',edgecolor='None',alpha=0.65))
savefig('ex_4.png',dpi=72)

show()

# %% [markdown]
# ####
